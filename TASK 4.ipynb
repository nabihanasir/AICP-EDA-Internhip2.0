# %% [markdown]
# # AICP Internship Task Week 4

# %% [markdown]
# <b>Q.1:Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file<b>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

df=pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df=df[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Vitamin A (% Daily Value)', 'Sugars', 'Protein', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Calories                   260 non-null    int64
#  1   Total Fat                  260 non-null    float64
#  2   Carbohydrates              260 non-null    int64
#  3   Dietary Fiber              260 non-null    int64
#  4   Vitamin A (% Daily Value)  260 non-null    int64
#  5   Sugars                     260 non-null    int64
#  6   Protein                    260 non-null    int64
#  7   Vitamin C (% Daily Value)  260 non-null    int64
#  8   Calcium (% Daily Value)    260 non-null    int64
#  9   Iron (% Daily Value)       260 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 20.4 KB

# %% [markdown]
# <b>Q.2: Check statistical facts by checking all columns. Then calculate the maximum value of the following
# attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%
# Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']<b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Calories                   260 non-null    int64
#  1   Total Fat                  260 non-null    float64
#  2   Carbohydrates              260 non-null    int64
#  3   Dietary Fiber              260 non-null    int64
#  4   Vitamin A (% Daily Value)  260 non-null    int64
#  5   Sugars                     260 non-null    int64
#  6   Protein                    260 non-null    int64
#  7   Vitamin C (% Daily Value)  260 non-null    int64
#  8   Calcium (% Daily Value)    260 non-null    int64
#  9   Iron (% Daily Value)       260 non-null    int64
# dtypes: float64(1), int64(9)
# memory usage: 20.4 KB

# %%
df.describe()
# Out:
#           Calories   Total Fat  Carbohydrates  Dietary Fiber  \
# count   260.000000  260.000000     260.000000     260.000000
# mean    368.269231   14.165385      47.346154       1.630769
# std     240.269886   14.205998      28.252232       1.567717
# min       0.000000    0.000000       0.000000       0.000000
# 25%     210.000000    2.375000      30.000000       0.000000
# 50%     340.000000   11.000000      44.000000       1.000000
# 75%     500.000000   22.250000      60.000000       3.000000
# max    1880.000000  118.000000     141.000000       7.000000
#
#        Vitamin A (% Daily Value)      Sugars     Protein  \
# count                 260.000000  260.000000  260.000000
# mean                   13.426923   29.423077   13.338462
# std                    24.366381   28.679797   11.426146
# min                     0.000000    0.000000    0.000000
# 25%                     2.000000    5.750000    4.000000
# 50%                     8.000000   17.500000   12.000000
# ...

# %%
df [['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']].max()
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# <b>Q.3: Check to see if infact there is any correlation between Calories and other independent variables by
# plotting a correlation matrix next.<b>

# %%
cm=df.corr()
sns.heatmap(cm)
plt.grid()
plt.show()

# %% [markdown]
# <b>Q.4: Draw boxplot for Calories vs Category to spot outliers and max calories category<b>

# %%
data=pd.read_csv('menu.csv')
sns.set_style('whitegrid')
sns.boxplot(data=data,x=data['Calories'],y=data['Category'],hue=data['Category'],legend='brief',width=0.1)

plt.show()

# %% [markdown]
# <b>Q.5: Figure out which exact item contains a high quantity for ['Calories', 'Total Fat', 'Carbohydrates',
# 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium
# (% Daily Value)', 'Iron (% Daily Value)'. Display summary link this:<b>

# %%
cols = data[['Calories', 'Total Fat', 'Carbohydrates','Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
for nutrient in cols.columns:
    max_index = data[nutrient].idxmax()
    item_name = data.loc[max_index, 'Item']
    nutrient_value = data.loc[max_index, nutrient]
    print(f"{nutrient} - {item_name}: {nutrient_value}")
# Out:
# Calories - Chicken McNuggets (40 piece): 1880
# Total Fat - Chicken McNuggets (40 piece): 118.0
# Carbohydrates - Chocolate Shake (Large): 141
# Dietary Fiber - Big Breakfast with Hotcakes (Large Biscuit): 7
# Sugars - McFlurry with M&M’s Candies (Medium): 128
# Protein - Chicken McNuggets (40 piece): 87
# Vitamin A (% Daily Value) - Premium Bacon Ranch Salad (without Chicken): 170
# Vitamin C (% Daily Value) - Minute Maid Orange Juice (Large): 240
# Calcium (% Daily Value) - Strawberry Shake (Large): 70
# Iron (% Daily Value) - Big Breakfast with Hotcakes (Regular Biscuit): 40

# %% [markdown]
# <b>Q.6: Draw Stripplot for each
# category against the following
# attributes ['Calories', 'Total Fat',
# 'Carbohydrates', 'Dietary
# Fiber', 'Sugars', 'Protein',
# 'Vitamin A (% Daily Value)',
# 'Vitamin C (% Daily Value)',
# 'Calcium (% Daily Value)', 'Iron
# (% Daily Value)'.
# Here is one sample, you have to
# do it for all above mentioned
# attributes in list.<b>

# %%
cols = data[['Calories', 'Total Fat', 'Carbohydrates','Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
for nutrient in cols.columns:
    sns.stripplot(x=data['Category'],y=data[nutrient],hue=data['Category'])
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# <b>Q.7: Draw a horizontal bar graph for items in each category against the calories.
# Here is one sample for all items in Beef & Pork, you have to do it for items in each category. Also, write
# your observation.
# <b>

# %%
grouped = data.groupby('Category')

for category, group_data in grouped:
    plt.figure(figsize=(10, 6))  # Adjust figure size if needed
    plt.barh(group_data['Item'], group_data['Calories'])
    plt.xlabel('Calories')
    plt.yticks(range(len(group_data['Item'])), group_data['Item'], fontsize=8)
    plt.ylabel('Item')
    plt.title(f'Calories in Items - {category}')
    plt.tight_layout()
    plt.show()
